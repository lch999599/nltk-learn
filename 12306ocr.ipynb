# %%
from PIL import Image
from matplotlib import pyplot as plt
import matplotlib
import os

# %%
# %matplotlib inline

# %%
im = Image.open("jpeg/5bbe6ef0b34338bc5884ae343cbe07de.jpeg")

# %%
plt.imshow(im)

# %%
gray = im.convert("L")

# %%
gray
# Out:
# <PIL.Image.Image image mode=L size=293x190 at 0x10DD55A20>

# %%
plt.imshow(gray)

# %%
img = plt.imread("jpeg/5bbe6ef0b34338bc5884ae343cbe07de.jpeg")

# %%
plt.imshow(img)

# %%
(293 - 5 * 5)/4
# Out:
# 67.0

# %%
img.shape
# Out:
# (190, 293, 3)

# %%
plt.imshow(img[0:28, 0:117, :])

# %%
plt.imshow(img[0:28, 118:, :])

# %%
plt.imshow(img[30:110, 5:72, :])

# %%
index = 1
for col in range(4):
    for row in range(2):
        plt.subplot(2, 4, index)
        x_start = 5 + (5+67) * col
        x_end = x_start + 67
        y_start = 30 + 11 + (5 + 67) * row
        y_end = y_start + 67
        plt.imshow(img[y_start:y_end, x_start:x_end, :])
        index += 1
#         break
#     break

# %%
plt.imshow(img)

# %%
l = os.listdir("jpeg/")

# %%
len(l)
# Out:
# 1667
